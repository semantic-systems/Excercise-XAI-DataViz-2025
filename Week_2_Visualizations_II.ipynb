# %% [markdown]
# # Visualisierungen II
#
# ## 1 Radar chart

# %%
import pandas as pd

# Load the CSV into a DataFrame; data from https://huggingface.co/spaces/open-llm-leaderboard/comparator; don't rely too much on the exact values!
df = pd.read_csv("data/llm_results.csv")
df
# Out:
#                                            Unnamed: 0  \
# 0                                        bbh.acc_norm
# 1                    bbh_boolean_expressions.acc_norm
# 2                       bbh_causal_judgement.acc_norm
# 3                     bbh_date_understanding.acc_norm
# 4                      bbh_disambiguation_qa.acc_norm
# 5                       bbh_formal_fallacies.acc_norm
# 6                       bbh_geometric_shapes.acc_norm
# 7                             bbh_hyperbaton.acc_norm
# 8         bbh_logical_deduction_five_objects.acc_norm
# 9        bbh_logical_deduction_seven_objects.acc_norm
# 10       bbh_logical_deduction_three_objects.acc_norm
# 11                  bbh_movie_recommendation.acc_norm
# 12                              bbh_navigate.acc_norm
# 13                       bbh_object_counting.acc_norm
# 14                   bbh_penguins_in_a_table.acc_norm
# 15       bbh_reasoning_about_colored_objects.acc_norm
# ...

# %% [markdown]
# ### Aufgabe 1.1
# Nutzen Sie die obigen daten, um das arithmetische Mittel der Haupt-Benchmarks (BBH, GPQA, IFEval, MATH, MMLU-Pro, MuSR) für jedes Modell zu berechnen.

# %% [markdown]
# ### Aufgabe 1.2
# Nutzen Sie die mehr-dimensionalen Vektoren (Lösung der vorherigen Aufgabe) und stellen Sie diese mittels sternförmiger Koordinaten (auch
# bekannt als Radar Plot, Star Plot, Kiviatgraph, ...) dar. Sie können sowohl Hexagone als auch Kreise als Koordinatensystem verwenden. Implementieren Sie den Code mittels Python und unter Zuhilfenahme der Matplotlib Bibliothek.
#
# ### Aufgabe 1.3 (Hausaufgabe)
# Finden Sie Daten, welche passend für die Visualisierung mittels eines Radar Charts sind. Falls Sie eigene Daten aus anderen Projekten etc haben, ist das auch super. Erstellen Sie ein Radar Chart mit diesen Daten.

# %% [markdown]
# ## 2 Barrierefreiheit
# Wie gut sind die Fotos auf der Leuphana-Webseite zugänglich für Menschen, welche einen Screenreader nutzen? Finden Sie Alternativtexte zum Beispiel auf dieser Seite: https://www.leuphana.de/einrichtungen/fakultaet/nachhaltigkeit/aktuell/ansicht/2025/04/15/artenreiche-waelder-koennen-klimaextreme-besser-abpuffern.html

# %% [markdown]
# ## 3 Interessante Visualisierung
# ### Aufgabe 3 (Hausaufgabe)
# Finden Sie eine interessanten Visualisierung aus dem Alltag, die viele Informationen verdichtet und zusammen zeigt. Erklären Sie den Inhalt der Visualisierung und begründen Sie Ihre Entscheidung kurz (max. 100 Wörter, gerne auch Stichpunkte) unter den Gesichtspunkten der letzten Vorlesung. Dazu kann auch zählen, wenn Sie Verbesserungsvorschläge haben.
#
#
#
# ## 4 Visualisierung von zeitlichen Entwicklungen
# ### Aufgabe 4 (Hausaufgabe)
# Nutzen Sie die Daten in data/web-browser.csv (Quelle: https://gs.statcounter.com/browser-market-share) und erstellen Sie eine möglichst aussagekräftige Visualisierung. Sie dürfen dafür egal welches Tool verwenden, bei dieser Aufgabe kommt es auf das Ergebnis an.
# Bedenken Sie: Was beschreiben die Daten, und wie lassen sie sich unter den Visualisierungsdimensionen Expressivität, Effektivität und Angemessenheit am besten darstellen? Welche Datenpunkte oder Variablen sind relevant?
# Ihre hypothetische Zielgruppe ist das Management ihres Webentwicklungsunternehmens, welches 2009 kollektiv untergetaucht ist und heute von Ihnen wissen möchte, für welchen Browser Sie Ihre Anwendung zuerst optimieren sollen.
